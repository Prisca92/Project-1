# %%
#Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
all_data = pd.read_csv("Resources/all_data_v3.csv")
all_data
# Out:
#      Unnamed: 0  Year_x  Period  Avg hrs per day sleeping  Standard Error  \
# 0             0    2003  Annual                      8.48           0.031
# 1             1    2004  Annual                      8.48           0.040
# 2             2    2005  Annual                      8.53           0.034
# 3             3    2006  Annual                      8.56           0.035
# 4             4    2007  Annual                      8.52           0.038
# ..          ...     ...     ...                       ...             ...
# 265         265    2016  Annual                      8.97           0.054
# 266         266    2016  Annual                      8.97           0.054
# 267         267    2017  Annual                      8.91           0.072
# 268         268    2017  Annual                      8.91           0.072
# 269         269    2017  Annual                      8.91           0.072
#
#     Type of Days        Age Group_x  Activity Gender_x  \
# ...

# %%
Hours_slept=all_data.groupby("Age Group_x")["Avg hrs per day sleeping"].mean()
Hours_slept
# Out:
# Age Group_x
# 15 to 24 years       9.348333
# 15 years and over    8.683667
# 25 to 34 years       8.636667
# 35 to 44 years       8.431333
# 45 to 54 years       8.336667
# 55 to 64 years       8.404667
# 65 years and over    8.924667
# Name: Avg hrs per day sleeping, dtype: float64

# %%
Age_Group_x=all_data.loc[all_data["Age Group_x"]=="15 to 24 years"]
Age_Group_x
# Out:
#      Unnamed: 0  Year_x  Period  Avg hrs per day sleeping  Standard Error  \
# 15           15    2003  Annual                      9.14           0.095
# 16           16    2004  Annual                      9.12           0.109
# 17           17    2005  Annual                      9.20           0.118
# 18           18    2006  Annual                      9.21           0.108
# 19           19    2007  Annual                      9.03           0.125
# 20           20    2008  Annual                      9.27           0.122
# 21           21    2009  Annual                      9.56           0.136
# 22           22    2010  Annual                      9.21           0.117
# 23           23    2011  Annual                      9.33           0.107
# 24           24    2012  Annual                      9.16           0.118
# 25           25    2013  Annual                      9.30           0.140
# 26           26    2014  Annual                      9.47           0.118
# ...

# %%
Age_Group_x["Age Group_x"].value_counts()
# Out:
# 15 to 24 years    30
# Name: Age Group_x, dtype: int64

# %%
#Avg sleep vs year
plot_pandas = Age_Group_x.groupby("Year_x")["Avg hrs per day sleeping"].mean()
plot_pandas.plot (kind="bar")
plt.title("Hours spent sleeping per Day for Ages 15-24")
plt.xlabel("Year")
plt.ylabel("Avg hrs per day sleeping")
plt.show()

# %%
plot_pandas = Age_Group_x.groupby("Year_x")["2022\ndollars"].mean()
plot_pandas.plot (kind="bar")
plt.title("Annual Income at Selected Year for Ages 15-24")
plt.xlabel("Year")
plt.ylabel("Annual Income(Dollars)")
plt.show()

# %%
plot_pandas = Age_Group_x.groupby("Year_x")["2022\ndollars"].mean()
plot_pandas.plot ()
plt.title("Annual Income at Selected Year for Ages 15-24")
plt.xlabel("Year")
plt.ylabel("Annual Income(Dollars)")
plt.show()

# %%
#Sleep vs income based on gender

plot_pandas = Age_Group_x.groupby("Avg hrs per day sleeping")["2022\ndollars"].mean()
plot_pandas.plot ()
plt.title("Annual Income Vs Average hrs of sleep for Ages 15-24")
plt.xlabel("Hrs of Sleep per day")
plt.ylabel("Annual Income(Dollars)")
plt.show()

# %%
#I want to do a gender comparison within this scatterplot

fig1, ax1 = plt.subplots()
avg_capm_vol =Age_Group_x.groupby('Avg hrs per day sleeping')['2022\ndollars'].mean()

marker_size=15
plt.scatter(Age_Group_x['Avg hrs per day sleeping'],Age_Group_x['2022\ndollars'], color="blue")
plt.title('Annual Income Vs Average hrs of sleep for Ages 15-24')
plt.xlabel('Average hours of Sleep',fontsize =10)
plt.ylabel('Annual Income(Dollars)')
plt.show()

# %%
filtered_female = Age_Group_x[Age_Group_x['Gender_x'] == "Female"]
filtered_female
# Out:
#      Unnamed: 0  Year_x  Period  Avg hrs per day sleeping  Standard Error  \
# 150         150    2003  Annual                      9.16           0.075
# 151         151    2004  Annual                      9.34           0.105
# 152         152    2005  Annual                      9.35           0.094
# 153         153    2006  Annual                      9.17           0.097
# 154         154    2007  Annual                      9.20           0.107
# 155         155    2008  Annual                      9.13           0.119
# 156         156    2009  Annual                      9.33           0.098
# 157         157    2010  Annual                      9.27           0.115
# 158         158    2011  Annual                      9.31           0.111
# 159         159    2012  Annual                      9.53           0.112
# 160         160    2013  Annual                      9.38           0.128
# 161         161    2014  Annual                      9.60           0.131
# ...

# %%
fig1, ax1 = plt.subplots()
avg_capm_vol =Age_Group_x.groupby('Avg hrs per day sleeping')['2022\ndollars'].mean()


marker_size=15
plt.scatter(filtered_female['Avg hrs per day sleeping'],filtered_female['2022\ndollars'], color="red")
plt.scatter(filtered_male['Avg hrs per day sleeping'],filtered_male['2022\ndollars'], color="blue")
plt.title('Annual Income Vs Average hrs of sleep for Ages 15-24')
plt.xlabel('Average hours of Sleep',fontsize =10)
plt.ylabel('Annual Income(Dollars)')

#print(f'The r-value is:{rvalue**2}')
plt.show()

# %%
filtered_male = Age_Group_x[Age_Group_x['Gender_x'] == "Male"]
filtered_male
# Out:
#     Unnamed: 0  Year_x  Period  Avg hrs per day sleeping  Standard Error  \
# 15          15    2003  Annual                      9.14           0.095
# 16          16    2004  Annual                      9.12           0.109
# 17          17    2005  Annual                      9.20           0.118
# 18          18    2006  Annual                      9.21           0.108
# 19          19    2007  Annual                      9.03           0.125
# 20          20    2008  Annual                      9.27           0.122
# 21          21    2009  Annual                      9.56           0.136
# 22          22    2010  Annual                      9.21           0.117
# 23          23    2011  Annual                      9.33           0.107
# 24          24    2012  Annual                      9.16           0.118
# 25          25    2013  Annual                      9.30           0.140
# 26          26    2014  Annual                      9.47           0.118
# ...

# %%
fig1, ax1 = plt.subplots()
avg_capm_vol =Age_Group_x.groupby('Avg hrs per day sleeping')['2022\ndollars'].mean()

marker_size=15
plt.scatter(filtered_male['Avg hrs per day sleeping'],filtered_male['2022\ndollars'], color="blue")
plt.title('Annual Income Vs Average hrs of sleep for Ages 15-24')
plt.xlabel('Average hours of Sleep',fontsize =10)
plt.ylabel('Annual Income(Dollars)')
plt.show()

# %%
Age_Group_x.corr()
# Out:
# /var/folders/zn/j9frgv4x3r37_sr8khbtnzyr0000gn/T/ipykernel_45688/3632210579.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Age_Group_x.corr()
#                                 Unnamed: 0    Year_x  \
# Unnamed: 0                        1.000000  0.063877
# Year_x                            0.063877  1.000000
# Avg hrs per day sleeping          0.170889  0.780931
# Standard Error                   -0.240654  0.769066
# Year_y                            0.063877  1.000000
# Number with income (thousands)   -0.592747 -0.235491
# Mean income                      -0.599745  0.688038
# 2022\ndollars                    -0.833766  0.250058
#
#                                 Avg hrs per day sleeping  Standard Error  \
# Unnamed: 0                                      0.170889       -0.240654
# ...

# %%
#copy_df=Age_Group_x.copy()
#copy_df.reset_index(inplace=True)
#copy_df.duplicated()

# %%
Age_Group_x.head(30)
# Out:
#      Unnamed: 0  Year_x  Period  Avg hrs per day sleeping  Standard Error  \
# 15           15    2003  Annual                      9.14           0.095
# 16           16    2004  Annual                      9.12           0.109
# 17           17    2005  Annual                      9.20           0.118
# 18           18    2006  Annual                      9.21           0.108
# 19           19    2007  Annual                      9.03           0.125
# 20           20    2008  Annual                      9.27           0.122
# 21           21    2009  Annual                      9.56           0.136
# 22           22    2010  Annual                      9.21           0.117
# 23           23    2011  Annual                      9.33           0.107
# 24           24    2012  Annual                      9.16           0.118
# 25           25    2013  Annual                      9.30           0.140
# 26           26    2014  Annual                      9.47           0.118
# ...

# %%
# Create the grouped bar chart
fig, ax = plt.subplots(figsize=(8, 6))

bar_width = 0.35
index = filtered_female.index

# Create a second y-axis for Hours of Sleep
ax2 = ax.twinx()

# Bars for Income
bar1 = ax.bar(index - bar_width / 2, filtered_female['2022\ndollars'], bar_width, label='Income (Female)', color='purple')
bar2 = ax.bar(index + bar_width / 2, filtered_male['2022\ndollars'], bar_width, label='Income (Male)', color='blue')

# Bars for Hours of Sleep
bar3 = ax2.bar(index - bar_width / 2, filtered_female['Avg hrs per day sleeping'], bar_width, label='Hours of Sleep (Female)', color='red', alpha=0.5)
bar4 = ax2.bar(index + bar_width / 2, filtered_male['Avg hrs per day sleeping'], bar_width, label='Hours of Sleep (Male)', color='green', alpha=0.5)

# Customize the plot with labels, titles, and legends
ax.set_xlabel('Years')
ax.set_ylabel('Annual Income (Dollars)')
ax2.set_ylabel('Hours of Sleep')
ax.set_title('Comparison of Income and Hours of Sleep by Gender for Ages 15-24')
ax.set_xticks(index)
ax.set_xticklabels(Age_Group_x['Year_x'].head(15))
ax.legend(loc='upper left')
ax2.legend(loc='lower right')

# Show the plot
plt.tight_layout()
plt.show()
